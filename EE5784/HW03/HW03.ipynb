# %% [markdown]
# # HW3 Image Classification
# ## We strongly recommend that you run with Kaggle for this homework

# %% [markdown]
# # Get Data
# Notes: if the links are dead, you can download the data directly from Kaggle and upload it to the workspace, or you can use the Kaggle API to directly download the data into colab.

# %%
! wget https://www.dropbox.com/s/6l2vcvxl54b0b6w/food11.zip
# Out:
# --2025-05-06 02:46:33--  https://www.dropbox.com/s/6l2vcvxl54b0b6w/food11.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.85.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.85.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/hjgabr8fbuvuzjvtp77b1/food11.zip?rlkey=nsgokn3hjmer9ss6p1v9aag98 [following]
# --2025-05-06 02:46:33--  https://www.dropbox.com/scl/fi/hjgabr8fbuvuzjvtp77b1/food11.zip?rlkey=nsgokn3hjmer9ss6p1v9aag98
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4f85166d75df59ed76daa1956f.dl.dropboxusercontent.com/cd/0/inline/CpGeVYmQzazgRqQm4oCC_NE3l0_JuqwrW0Hgld2HdWwLf1MHQLi5rUXMXlXCKfSw3nuNqxSRuPwJ3N4oNtL3iLzgmDVWd0SvQzCAMfjsMwh2VxiJ7-ZPy7vI5Lz5ZU-mjFnHPkQ7JL14dwN9K2wkGyV6/file# [following]
# --2025-05-06 02:46:34--  https://uc4f85166d75df59ed76daa1956f.dl.dropboxusercontent.com/cd/0/inline/CpGeVYmQzazgRqQm4oCC_NE3l0_JuqwrW0Hgld2HdWwLf1MHQLi5rUXMXlXCKfSw3nuNqxSRuPwJ3N4oNtL3iLzgmDVWd0SvQzCAMfjsMwh2VxiJ7-ZPy7vI5Lz5ZU-mjFnHPkQ7JL14dwN9K2wkGyV6/file
# Resolving uc4f85166d75df59ed76daa1956f.dl.dropboxusercontent.com (uc4f85166d75df59ed76daa1956f.dl.dropboxusercontent.com)... 162.125.85.15, 2620:100:6035:15::a27d:550f
# Connecting to uc4f85166d75df59ed76daa1956f.dl.dropboxusercontent.com (uc4f85166d75df59ed76daa1956f.dl.dropboxusercontent.com)|162.125.85.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CpHTizAMe9uQSnWb61QHiAGKQsPkzO_9zNns0V7QAPD9qKGMuXyyuEass-8YVi4brNs5Sx2DJBNpKbimFFC5hQy43MdvdvDLtwmmZjraj16JQHEmDde6Uu4bIqEz0FFcfjlludgV16Vpv-npvAMynHNk6D8oh3U-TLgYwHwzTsOlleAVkAF19KsehosuPH1eE4GFHv-GeeQEQ8ECSosihjoqgA1YaBqXH4XEiXzQGhH2iHV2Z99wsK-CZLoFrDH2P0FfL7UBo3_2aXtlpuTUfesWPVdm0M5CLs3iU1Sgsha3jgxkejTtTqbSawmo3ehvYoNXMlHPLeD-196mjz-J_GPK-gbVyCTVGS2wac7gWC4q6NUNXkqFlVlFH2tsxyc4FRU/file [following]
# --2025-05-06 02:46:34--  https://uc4f85166d75df59ed76daa1956f.dl.dropboxusercontent.com/cd/0/inline2/CpHTizAMe9uQSnWb61QHiAGKQsPkzO_9zNns0V7QAPD9qKGMuXyyuEass-8YVi4brNs5Sx2DJBNpKbimFFC5hQy43MdvdvDLtwmmZjraj16JQHEmDde6Uu4bIqEz0FFcfjlludgV16Vpv-npvAMynHNk6D8oh3U-TLgYwHwzTsOlleAVkAF19KsehosuPH1eE4GFHv-GeeQEQ8ECSosihjoqgA1YaBqXH4XEiXzQGhH2iHV2Z99wsK-CZLoFrDH2P0FfL7UBo3_2aXtlpuTUfesWPVdm0M5CLs3iU1Sgsha3jgxkejTtTqbSawmo3ehvYoNXMlHPLeD-196mjz-J_GPK-gbVyCTVGS2wac7gWC4q6NUNXkqFlVlFH2tsxyc4FRU/file
# Reusing existing connection to uc4f85166d75df59ed76daa1956f.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1163077597 (1.1G) [application/zip]
# Saving to: ‘food11.zip’
#
# food11.zip          100%[===================>]   1.08G  18.5MB/s    in 66s
#
# 2025-05-06 02:47:41 (16.8 MB/s) - ‘food11.zip’ saved [1163077597/1163077597]

# %%
! unzip food11.zip
# Out:
# Archive:  food11.zip
#    creating: food11/
#    creating: food11/test/
#   inflating: food11/test/0001.jpg
#   inflating: food11/test/0002.jpg
#   inflating: food11/test/0003.jpg
#   inflating: food11/test/0004.jpg
#   inflating: food11/test/0005.jpg
#   inflating: food11/test/0006.jpg
#   inflating: food11/test/0007.jpg
#   inflating: food11/test/0008.jpg
#   inflating: food11/test/0009.jpg
#   inflating: food11/test/0010.jpg
#   inflating: food11/test/0011.jpg
#   inflating: food11/test/0012.jpg
#   inflating: food11/test/0013.jpg
#   inflating: food11/test/0014.jpg
#   inflating: food11/test/0015.jpg
#   inflating: food11/test/0016.jpg
#   inflating: food11/test/0017.jpg
#   inflating: food11/test/0018.jpg
#   inflating: food11/test/0019.jpg
#   inflating: food11/test/0020.jpg
#   inflating: food11/test/0021.jpg
#   inflating: food11/test/0022.jpg
#   inflating: food11/test/0023.jpg
#   inflating: food11/test/0024.jpg
#   inflating: food11/test/0025.jpg
#   inflating: food11/test/0026.jpg
#  extracting: food11/test/0027.jpg
#   inflating: food11/test/0028.jpg
#   inflating: food11/test/0029.jpg
#   inflating: food11/test/0030.jpg
#   inflating: food11/test/0031.jpg
#   inflating: food11/test/0032.jpg
#   inflating: food11/test/0033.jpg
#   inflating: food11/test/0034.jpg
#   inflating: food11/test/0035.jpg
#   inflating: food11/test/0036.jpg
#   inflating: food11/test/0037.jpg
#   inflating: food11/test/0038.jpg
#   inflating: food11/test/0039.jpg
#   inflating: food11/test/0040.jpg
#   inflating: food11/test/0041.jpg
#   inflating: food11/test/0042.jpg
#   inflating: food11/test/0043.jpg
#   inflating: food11/test/0044.jpg
#   inflating: food11/test/0045.jpg
#   inflating: food11/test/0046.jpg
#   inflating: food11/test/0047.jpg
#   inflating: food11/test/0048.jpg
#   inflating: food11/test/0049.jpg
#   inflating: food11/test/0050.jpg
#   inflating: food11/test/0051.jpg
#   inflating: food11/test/0052.jpg
#   inflating: food11/test/0053.jpg
#  extracting: food11/test/0054.jpg
#   inflating: food11/test/0055.jpg
#   inflating: food11/test/0056.jpg
#   inflating: food11/test/0057.jpg
#   inflating: food11/test/0058.jpg
#   inflating: food11/test/0059.jpg
#   inflating: food11/test/0060.jpg
#   inflating: food11/test/0061.jpg
#   inflating: food11/test/0062.jpg
#   inflating: food11/test/0063.jpg
#   inflating: food11/test/0064.jpg
#   inflating: food11/test/0065.jpg
#   inflating: food11/test/0066.jpg
#   inflating: food11/test/0067.jpg
#   inflating: food11/test/0068.jpg
#   inflating: food11/test/0069.jpg
#   inflating: food11/test/0070.jpg
#   inflating: food11/test/0071.jpg
#   inflating: food11/test/0072.jpg
#   inflating: food11/test/0073.jpg
#   inflating: food11/test/0074.jpg
#   inflating: food11/test/0075.jpg
#   inflating: food11/test/0076.jpg
#   inflating: food11/test/0077.jpg
#   inflating: food11/test/0078.jpg
#   inflating: food11/test/0079.jpg
#   inflating: food11/test/0080.jpg
#   inflating: food11/test/0081.jpg
#   inflating: food11/test/0082.jpg
#   inflating: food11/test/0083.jpg
#   inflating: food11/test/0084.jpg
#   inflating: food11/test/0085.jpg
#   inflating: food11/test/0086.jpg
#   inflating: food11/test/0087.jpg
#   inflating: food11/test/0088.jpg
#   inflating: food11/test/0089.jpg
#   inflating: food11/test/0090.jpg
#   inflating: food11/test/0091.jpg
#   inflating: food11/test/0092.jpg
#   inflating: food11/test/0093.jpg
#   inflating: food11/test/0094.jpg
#   inflating: food11/test/0095.jpg
#   inflating: food11/test/0096.jpg
#   inflating: food11/test/0097.jpg
#   inflating: food11/test/0098.jpg
#   inflating: food11/test/0099.jpg
#   inflating: food11/test/0100.jpg
#   inflating: food11/test/0101.jpg
#   inflating: food11/test/0102.jpg
#   inflating: food11/test/0103.jpg
#   inflating: food11/test/0104.jpg
#   inflating: food11/test/0105.jpg
#   inflating: food11/test/0106.jpg
#   inflating: food11/test/0107.jpg
#   inflating: food11/test/0108.jpg
#   inflating: food11/test/0109.jpg
#   inflating: food11/test/0110.jpg
#   inflating: food11/test/0111.jpg
#   inflating: food11/test/0112.jpg
#   inflating: food11/test/0113.jpg
#   inflating: food11/test/0114.jpg
#   inflating: food11/test/0115.jpg
#   inflating: food11/test/0116.jpg
#   inflating: food11/test/0117.jpg
#   inflating: food11/test/0118.jpg
#   inflating: food11/test/0119.jpg
#   inflating: food11/test/0120.jpg
#   inflating: food11/test/0121.jpg
#   inflating: food11/test/0122.jpg
#   inflating: food11/test/0123.jpg
#   inflating: food11/test/0124.jpg
#   inflating: food11/test/0125.jpg
#   inflating: food11/test/0126.jpg
#   inflating: food11/test/0127.jpg
#   inflating: food11/test/0128.jpg
#   inflating: food11/test/0129.jpg
#   inflating: food11/test/0130.jpg
#   inflating: food11/test/0131.jpg
#   inflating: food11/test/0132.jpg
#   inflating: food11/test/0133.jpg
#   inflating: food11/test/0134.jpg
#   inflating: food11/test/0135.jpg
#   inflating: food11/test/0136.jpg
#   inflating: food11/test/0137.jpg
#   inflating: food11/test/0138.jpg
#   inflating: food11/test/0139.jpg
#   inflating: food11/test/0140.jpg
#   inflating: food11/test/0141.jpg
#   inflating: food11/test/0142.jpg
#   inflating: food11/test/0143.jpg
#   inflating: food11/test/0144.jpg
#   inflating: food11/test/0145.jpg
#   inflating: food11/test/0146.jpg
#   inflating: food11/test/0147.jpg
#   inflating: food11/test/0148.jpg
#   inflating: food11/test/0149.jpg
#   inflating: food11/test/0150.jpg
#   inflating: food11/test/0151.jpg
#   inflating: food11/test/0152.jpg
#   inflating: food11/test/0153.jpg
#   inflating: food11/test/0154.jpg
#   inflating: food11/test/0155.jpg
#   inflating: food11/test/0156.jpg
#   inflating: food11/test/0157.jpg
#   inflating: food11/test/0158.jpg
#   inflating: food11/test/0159.jpg
#   inflating: food11/test/0160.jpg
#   inflating: food11/test/0161.jpg
#   inflating: food11/test/0162.jpg
#   inflating: food11/test/0163.jpg
#   inflating: food11/test/0164.jpg
#   inflating: food11/test/0165.jpg
#   inflating: food11/test/0166.jpg
#   inflating: food11/test/0167.jpg
#   inflating: food11/test/0168.jpg
#   inflating: food11/test/0169.jpg
#   inflating: food11/test/0170.jpg
#   inflating: food11/test/0171.jpg
#   inflating: food11/test/0172.jpg
#   inflating: food11/test/0173.jpg
#   inflating: food11/test/0174.jpg
#   inflating: food11/test/0175.jpg
#   inflating: food11/test/0176.jpg
#   inflating: food11/test/0177.jpg
#   inflating: food11/test/0178.jpg
#   inflating: food11/test/0179.jpg
#   inflating: food11/test/0180.jpg
#   inflating: food11/test/0181.jpg
#   inflating: food11/test/0182.jpg
#   inflating: food11/test/0183.jpg
#   inflating: food11/test/0184.jpg
#   inflating: food11/test/0185.jpg
#   inflating: food11/test/0186.jpg
#   inflating: food11/test/0187.jpg
#   inflating: food11/test/0188.jpg
#   inflating: food11/test/0189.jpg
#   inflating: food11/test/0190.jpg
#   inflating: food11/test/0191.jpg
#   inflating: food11/test/0192.jpg
#   inflating: food11/test/0193.jpg
#   inflating: food11/test/0194.jpg
#   inflating: food11/test/0195.jpg
#   inflating: food11/test/0196.jpg
#   inflating: food11/test/0197.jpg
#   inflating: food11/test/0198.jpg
#   inflating: food11/test/0199.jpg
#   inflating: food11/test/0200.jpg
#   inflating: food11/test/0201.jpg
#   inflating: food11/test/0202.jpg
#   inflating: food11/test/0203.jpg
#   inflating: food11/test/0204.jpg
#   inflating: food11/test/0205.jpg
#   inflating: food11/test/0206.jpg
#   inflating: food11/test/0207.jpg
#   inflating: food11/test/0208.jpg
#   inflating: food11/test/0209.jpg
#   inflating: food11/test/0210.jpg
#   inflating: food11/test/0211.jpg
#   inflating: food11/test/0212.jpg
#   inflating: food11/test/0213.jpg
#   inflating: food11/test/0214.jpg
#   inflating: food11/test/0215.jpg
#   inflating: food11/test/0216.jpg
#   inflating: food11/test/0217.jpg
#  extracting: food11/test/0218.jpg
#   inflating: food11/test/0219.jpg
#   inflating: food11/test/0220.jpg
#   inflating: food11/test/0221.jpg
#   inflating: food11/test/0222.jpg
#   inflating: food11/test/0223.jpg
#   inflating: food11/test/0224.jpg
#   inflating: food11/test/0225.jpg
#   inflating: food11/test/0226.jpg
#   inflating: food11/test/0227.jpg
#   inflating: food11/test/0228.jpg
#   inflating: food11/test/0229.jpg
#   inflating: food11/test/0230.jpg
#   inflating: food11/test/0231.jpg
#   inflating: food11/test/0232.jpg
#   inflating: food11/test/0233.jpg
#   inflating: food11/test/0234.jpg
#   inflating: food11/test/0235.jpg
#   inflating: food11/test/0236.jpg
#  extracting: food11/test/0237.jpg
#   inflating: food11/test/0238.jpg
#   inflating: food11/test/0239.jpg
#   inflating: food11/test/0240.jpg
#   inflating: food11/test/0241.jpg
#   inflating: food11/test/0242.jpg
#   inflating: food11/test/0243.jpg
#   inflating: food11/test/0244.jpg
#   inflating: food11/test/0245.jpg
#   inflating: food11/test/0246.jpg
#   inflating: food11/test/0247.jpg
#   inflating: food11/test/0248.jpg
#   inflating: food11/test/0249.jpg
#   inflating: food11/test/0250.jpg
#   inflating: food11/test/0251.jpg
#   inflating: food11/test/0252.jpg
#   inflating: food11/test/0253.jpg
#   inflating: food11/test/0254.jpg
#   inflating: food11/test/0255.jpg
#   inflating: food11/test/0256.jpg
#   inflating: food11/test/0257.jpg
#   inflating: food11/test/0258.jpg
#   inflating: food11/test/0259.jpg
#   inflating: food11/test/0260.jpg
#   inflating: food11/test/0261.jpg
#   inflating: food11/test/0262.jpg
#   inflating: food11/test/0263.jpg
#   inflating: food11/test/0264.jpg
#   inflating: food11/test/0265.jpg
#   inflating: food11/test/0266.jpg
#   inflating: food11/test/0267.jpg
#   inflating: food11/test/0268.jpg
#   inflating: food11/test/0269.jpg
#   inflating: food11/test/0270.jpg
#   inflating: food11/test/0271.jpg
#   inflating: food11/test/0272.jpg
#   inflating: food11/test/0273.jpg
#   inflating: food11/test/0274.jpg
#   inflating: food11/test/0275.jpg
#   inflating: food11/test/0276.jpg
#   inflating: food11/test/0277.jpg
#   inflating: food11/test/0278.jpg
#   inflating: food11/test/0279.jpg
#   inflating: food11/test/0280.jpg
#   inflating: food11/test/0281.jpg
#   inflating: food11/test/0282.jpg
#   inflating: food11/test/0283.jpg
#   inflating: food11/test/0284.jpg
#   inflating: food11/test/0285.jpg
#   inflating: food11/test/0286.jpg
#   inflating: food11/test/0287.jpg
#   inflating: food11/test/0288.jpg
#   inflating: food11/test/0289.jpg
#   inflating: food11/test/0290.jpg
#   inflating: food11/test/0291.jpg
#   inflating: food11/test/0292.jpg
#   inflating: food11/test/0293.jpg
#   inflating: food11/test/0294.jpg
#   inflating: food11/test/0295.jpg
#   inflating: food11/test/0296.jpg
#   inflating: food11/test/0297.jpg
#   inflating: food11/test/0298.jpg
#   inflating: food11/test/0299.jpg
#   inflating: food11/test/0300.jpg
#   inflating: food11/test/0301.jpg
#   inflating: food11/test/0302.jpg
#   inflating: food11/test/0303.jpg
#   inflating: food11/test/0304.jpg
#   inflating: food11/test/0305.jpg
#   inflating: food11/test/0306.jpg
#   inflating: food11/test/0307.jpg
#   inflating: food11/test/0308.jpg
#   inflating: food11/test/0309.jpg
#   inflating: food11/test/0310.jpg
#   inflating: food11/test/0311.jpg
#   inflating: food11/test/0312.jpg
#   inflating: food11/test/0313.jpg
#   inflating: food11/test/0314.jpg
#   inflating: food11/test/0315.jpg
#  extracting: food11/test/0316.jpg
#   inflating: food11/test/0317.jpg
#   inflating: food11/test/0318.jpg
#   inflating: food11/test/0319.jpg
#   inflating: food11/test/0320.jpg
#   inflating: food11/test/0321.jpg
#   inflating: food11/test/0322.jpg
#   inflating: food11/test/0323.jpg
#   inflating: food11/test/0324.jpg
#   inflating: food11/test/0325.jpg
#   inflating: food11/test/0326.jpg
#   inflating: food11/test/0327.jpg
#   inflating: food11/test/0328.jpg
#   inflating: food11/test/0329.jpg
#   inflating: food11/test/0330.jpg
#   inflating: food11/test/0331.jpg
#   inflating: food11/test/0332.jpg
#   inflating: food11/test/0333.jpg
#   inflating: food11/test/0334.jpg
#   inflating: food11/test/0335.jpg
#   inflating: food11/test/0336.jpg
#   inflating: food11/test/0337.jpg
#   inflating: food11/test/0338.jpg
#   inflating: food11/test/0339.jpg
#   inflating: food11/test/0340.jpg
#   inflating: food11/test/0341.jpg
#   inflating: food11/test/0342.jpg
#   inflating: food11/test/0343.jpg
#   inflating: food11/test/0344.jpg
#   inflating: food11/test/0345.jpg
#   inflating: food11/test/0346.jpg
#   inflating: food11/test/0347.jpg
#   inflating: food11/test/0348.jpg
#   inflating: food11/test/0349.jpg
#   inflating: food11/test/0350.jpg
#   inflating: food11/test/0351.jpg
#   inflating: food11/test/0352.jpg
#  extracting: food11/test/0353.jpg
#   inflating: food11/test/0354.jpg
#   inflating: food11/test/0355.jpg
#   inflating: food11/test/0356.jpg
#   inflating: food11/test/0357.jpg
#   inflating: food11/test/0358.jpg
#   inflating: food11/test/0359.jpg
#   inflating: food11/test/0360.jpg
#   inflating: food11/test/0361.jpg
#   inflating: food11/test/0362.jpg
#   inflating: food11/test/0363.jpg
#   inflating: food11/test/0364.jpg
#   inflating: food11/test/0365.jpg
#   inflating: food11/test/0366.jpg
#   inflating: food11/test/0367.jpg
#   inflating: food11/test/0368.jpg
#   inflating: food11/test/0369.jpg
#   inflating: food11/test/0370.jpg
#   inflating: food11/test/0371.jpg
#   inflating: food11/test/0372.jpg
#   inflating: food11/test/0373.jpg
#   inflating: food11/test/0374.jpg
#   inflating: food11/test/0375.jpg
#   inflating: food11/test/0376.jpg
#   inflating: food11/test/0377.jpg
#   inflating: food11/test/0378.jpg
#   inflating: food11/test/0379.jpg
#   inflating: food11/test/0380.jpg
#   inflating: food11/test/0381.jpg
#   inflating: food11/test/0382.jpg
#   inflating: food11/test/0383.jpg
#   inflating: food11/test/0384.jpg
#   inflating: food11/test/0385.jpg
#   inflating: food11/test/0386.jpg
#   inflating: food11/test/0387.jpg
#   inflating: food11/test/0388.jpg
#   inflating: food11/test/0389.jpg
#   inflating: food11/test/0390.jpg
#   inflating: food11/test/0391.jpg
#  extracting: food11/test/0392.jpg
#   inflating: food11/test/0393.jpg
#   inflating: food11/test/0394.jpg
#   inflating: food11/test/0395.jpg
#   inflating: food11/test/0396.jpg
#   inflating: food11/test/0397.jpg
#   inflating: food11/test/0398.jpg
#   inflating: food11/test/0399.jpg
#   inflating: food11/test/0400.jpg
#   inflating: food11/test/0401.jpg
#   inflating: food11/test/0402.jpg
#   inflating: food11/test/0403.jpg
#   inflating: food11/test/0404.jpg
#   inflating: food11/test/0405.jpg
#   inflating: food11/test/0406.jpg
#   inflating: food11/test/0407.jpg
#   inflating: food11/test/0408.jpg
#   inflating: food11/test/0409.jpg
#   inflating: food11/test/0410.jpg
#   inflating: food11/test/0411.jpg
#   inflating: food11/test/0412.jpg
#   inflating: food11/test/0413.jpg
#   inflating: food11/test/0414.jpg
#   inflating: food11/test/0415.jpg
#   inflating: food11/test/0416.jpg
#   inflating: food11/test/0417.jpg
#   inflating: food11/test/0418.jpg
#   inflating: food11/test/0419.jpg
#   inflating: food11/test/0420.jpg
#   inflating: food11/test/0421.jpg
#   inflating: food11/test/0422.jpg
#   inflating: food11/test/0423.jpg
#   inflating: food11/test/0424.jpg
#   inflating: food11/test/0425.jpg
#   inflating: food11/test/0426.jpg
#   inflating: food11/test/0427.jpg
#   inflating: food11/test/0428.jpg
#   inflating: food11/test/0429.jpg
#   inflating: food11/test/0430.jpg
#   inflating: food11/test/0431.jpg
#   inflating: food11/test/0432.jpg
#   inflating: food11/test/0433.jpg
#   inflating: food11/test/0434.jpg
#   inflating: food11/test/0435.jpg
#   inflating: food11/test/0436.jpg
#   inflating: food11/test/0437.jpg
#   inflating: food11/test/0438.jpg
#   inflating: food11/test/0439.jpg
#   inflating: food11/test/0440.jpg
#   inflating: food11/test/0441.jpg
#   inflating: food11/test/0442.jpg
#   inflating: food11/test/0443.jpg
#   inflating: food11/test/0444.jpg
#   inflating: food11/test/0445.jpg
#   inflating: food11/test/0446.jpg
#   inflating: food11/test/0447.jpg
#   inflating: food11/test/0448.jpg
#   inflating: food11/test/0449.jpg
#   inflating: food11/test/0450.jpg
#   inflating: food11/test/0451.jpg
#   inflating: food11/test/0452.jpg
#   inflating: food11/test/0453.jpg
#   inflating: food11/test/0454.jpg
#   inflating: food11/test/0455.jpg
#   inflating: food11/test/0456.jpg
#   inflating: food11/test/0457.jpg
#   inflating: food11/test/0458.jpg
#   inflating: food11/test/0459.jpg
#   inflating: food11/test/0460.jpg
#   inflating: food11/test/0461.jpg
#   inflating: food11/test/0462.jpg
#   inflating: food11/test/0463.jpg
#   inflating: food11/test/0464.jpg
#   inflating: food11/test/0465.jpg
#   inflating: food11/test/0466.jpg
#   inflating: food11/test/0467.jpg
#   inflating: food11/test/0468.jpg
#   inflating: food11/test/0469.jpg
#   inflating: food11/test/0470.jpg
#  extracting: food11/test/0471.jpg
#   inflating: food11/test/0472.jpg
#   inflating: food11/test/0473.jpg
#   inflating: food11/test/0474.jpg
#   inflating: food11/test/0475.jpg
#   inflating: food11/test/0476.jpg
#   inflating: food11/test/0477.jpg
#   inflating: food11/test/0478.jpg
#   inflating: food11/test/0479.jpg
#   inflating: food11/test/0480.jpg
#   inflating: food11/test/0481.jpg
#   inflating: food11/test/0482.jpg
#   inflating: food11/test/0483.jpg
#   inflating: food11/test/0484.jpg
#   inflating: food11/test/0485.jpg
#   inflating: food11/test/0486.jpg
#   inflating: food11/test/0487.jpg
#   inflating: food11/test/0488.jpg
#   inflating: food11/test/0489.jpg
#   inflating: food11/test/0490.jpg
#   inflating: food11/test/0491.jpg
#   inflating: food11/test/0492.jpg
#   inflating: food11/test/0493.jpg
#   inflating: food11/test/0494.jpg
#   inflating: food11/test/0495.jpg
#   inflating: food11/test/0496.jpg
#   inflating: food11/test/0497.jpg
#   inflating: food11/test/0498.jpg
#   inflating: food11/test/0499.jpg
#   inflating: food11/test/0500.jpg
#   inflating: food11/test/0501.jpg
#   inflating: food11/test/0502.jpg
#   inflating: food11/test/0503.jpg
#   inflating: food11/test/0504.jpg
#   inflating: food11/test/0505.jpg
#   inflating: food11/test/0506.jpg
#   inflating: food11/test/0507.jpg
#   inflating: food11/test/0508.jpg
#   inflating: food11/test/0509.jpg
#   inflating: food11/test/0510.jpg
#   inflating: food11/test/0511.jpg
#   inflating: food11/test/0512.jpg
#   inflating: food11/test/0513.jpg
#   inflating: food11/test/0514.jpg
#   inflating: food11/test/0515.jpg
#   inflating: food11/test/0516.jpg
#   inflating: food11/test/0517.jpg
#   inflating: food11/test/0518.jpg
#   inflating: food11/test/0519.jpg
#   inflating: food11/test/0520.jpg
#   inflating: food11/test/0521.jpg
#   inflating: food11/test/0522.jpg
#   inflating: food11/test/0523.jpg
#   inflating: food11/test/0524.jpg
#   inflating: food11/test/0525.jpg
#   inflating: food11/test/0526.jpg
#   inflating: food11/test/0527.jpg
#   inflating: food11/test/0528.jpg
#   inflating: food11/test/0529.jpg
#   inflating: food11/test/0530.jpg
#   inflating: food11/test/0531.jpg
#   inflating: food11/test/0532.jpg
#   inflating: food11/test/0533.jpg
#   inflating: food11/test/0534.jpg
#   inflating: food11/test/0535.jpg
#   inflating: food11/test/0536.jpg
#   inflating: food11/test/0537.jpg
#   inflating: food11/test/0538.jpg
#   inflating: food11/test/0539.jpg
#   inflating: food11/test/0540.jpg
#   inflating: food11/test/0541.jpg
#   inflating: food11/test/0542.jpg
#   inflating: food11/test/0543.jpg
#   inflating: food11/test/0544.jpg
#   inflating: food11/test/0545.jpg
#   inflating: food11/test/0546.jpg
#   inflating: food11/test/0547.jpg
#   inflating: food11/test/0548.jpg
#   inflating: food11/test/0549.jpg
#   inflating: food11/test/0550.jpg
#   inflating: food11/test/0551.jpg
#   inflating: food11/test/0552.jpg
#   inflating: food11/test/0553.jpg
#   inflating: food11/test/0554.jpg
#   inflating: food11/test/0555.jpg
#   inflating: food11/test/0556.jpg
#   inflating: food11/test/0557.jpg
#   inflating: food11/test/0558.jpg
#   inflating: food11/test/0559.jpg
#   inflating: food11/test/0560.jpg
#   inflating: food11/test/0561.jpg
#   inflating: food11/test/0562.jpg
#   inflating: food11/test/0563.jpg
#   inflating: food11/test/0564.jpg
#   inflating: food11/test/0565.jpg
#   inflating: food11/test/0566.jpg
#   inflating: food11/test/0567.jpg
#   inflating: food11/test/0568.jpg
#   inflating: food11/test/0569.jpg
#   inflating: food11/test/0570.jpg
#   inflating: food11/test/0571.jpg
#   inflating: food11/test/0572.jpg
#   inflating: food11/test/0573.jpg
#   inflating: food11/test/0574.jpg
#   inflating: food11/test/0575.jpg
#   inflating: food11/test/0576.jpg
#   inflating: food11/test/0577.jpg
#   inflating: food11/test/0578.jpg
#   inflating: food11/test/0579.jpg
#   inflating: food11/test/0580.jpg
#   inflating: food11/test/0581.jpg
#   inflating: food11/test/0582.jpg
#   inflating: food11/test/0583.jpg
#   inflating: food11/test/0584.jpg
#   inflating: food11/test/0585.jpg
#   inflating: food11/test/0586.jpg
#   inflating: food11/test/0587.jpg
#   inflating: food11/test/0588.jpg
#   inflating: food11/test/0589.jpg
#   inflating: food11/test/0590.jpg
#   inflating: food11/test/0591.jpg
#   inflating: food11/test/0592.jpg
#   inflating: food11/test/0593.jpg
#   inflating: food11/test/0594.jpg
#   inflating: food11/test/0595.jpg
#   inflating: food11/test/0596.jpg
#   inflating: food11/test/0597.jpg
#   inflating: food11/test/0598.jpg
#   inflating: food11/test/0599.jpg
#   inflating: food11/test/0600.jpg
#   inflating: food11/test/0601.jpg
#   inflating: food11/test/0602.jpg
#   inflating: food11/test/0603.jpg
#   inflating: food11/test/0604.jpg
#   inflating: food11/test/0605.jpg
#   inflating: food11/test/0606.jpg
#   inflating: food11/test/0607.jpg
#   inflating: food11/test/0608.jpg
#   inflating: food11/test/0609.jpg
#   inflating: food11/test/0610.jpg
#   inflating: food11/test/0611.jpg
#   inflating: food11/test/0612.jpg
#   inflating: food11/test/0613.jpg
#   inflating: food11/test/0614.jpg
#   inflating: food11/test/0615.jpg
#   inflating: food11/test/0616.jpg
#   inflating: food11/test/0617.jpg
#   inflating: food11/test/0618.jpg
#   inflating: food11/test/0619.jpg
#   inflating: food11/test/0620.jpg
#   inflating: food11/test/0621.jpg
#   inflating: food11/test/0622.jpg
#   inflating: food11/test/0623.jpg
#   inflating: food11/test/0624.jpg
#   inflating: food11/test/0625.jpg
#   inflating: food11/test/0626.jpg
#   inflating: food11/test/0627.jpg
#   inflating: food11/test/0628.jpg
#   inflating: food11/test/0629.jpg
#   inflating: food11/test/0630.jpg
#   inflating: food11/test/0631.jpg
#   inflating: food11/test/0632.jpg
#   inflating: food11/test/0633.jpg
#   inflating: food11/test/0634.jpg
#   inflating: food11/test/0635.jpg
#   inflating: food11/test/0636.jpg
#   inflating: food11/test/0637.jpg
#   inflating: food11/test/0638.jpg
#   inflating: food11/test/0639.jpg
#   inflating: food11/test/0640.jpg
#   inflating: food11/test/0641.jpg
#   inflating: food11/test/0642.jpg
#   inflating: food11/test/0643.jpg
#   inflating: food11/test/0644.jpg
#   inflating: food11/test/0645.jpg
#   inflating: food11/test/0646.jpg
#   inflating: food11/test/0647.jpg
#   inflating: food11/test/0648.jpg
#   inflating: food11/test/0649.jpg
#   inflating: food11/test/0650.jpg
#   inflating: food11/test/0651.jpg
#   inflating: food11/test/0652.jpg
#   inflating: food11/test/0653.jpg
#   inflating: food11/test/0654.jpg
#   inflating: food11/test/0655.jpg
#   inflating: food11/test/0656.jpg
#   inflating: food11/test/0657.jpg
#   inflating: food11/test/0658.jpg
#   inflating: food11/test/0659.jpg
#   inflating: food11/test/0660.jpg
#   inflating: food11/test/0661.jpg
#   inflating: food11/test/0662.jpg
#   inflating: food11/test/0663.jpg
#   inflating: food11/test/0664.jpg
#   inflating: food11/test/0665.jpg
#   inflating: food11/test/0666.jpg
#   inflating: food11/test/0667.jpg
#   inflating: food11/test/0668.jpg
#   inflating: food11/test/0669.jpg
#   inflating: food11/test/0670.jpg
#   inflating: food11/test/0671.jpg
#   inflating: food11/test/0672.jpg
#   inflating: food11/test/0673.jpg
#   inflating: food11/test/0674.jpg
#   inflating: food11/test/0675.jpg
#   inflating: food11/test/0676.jpg
#   inflating: food11/test/0677.jpg
#   inflating: food11/test/0678.jpg
#   inflating: food11/test/0679.jpg
#   inflating: food11/test/0680.jpg
#   inflating: food11/test/0681.jpg
#   inflating: food11/test/0682.jpg
#   inflating: food11/test/0683.jpg
#   inflating: food11/test/0684.jpg
#   inflating: food11/test/0685.jpg
#   inflating: food11/test/0686.jpg
#   inflating: food11/test/0687.jpg
#   inflating: food11/test/0688.jpg
#   inflating: food11/test/0689.jpg
#   inflating: food11/test/0690.jpg
#   inflating: food11/test/0691.jpg
#   inflating: food11/test/0692.jpg
#   inflating: food11/test/0693.jpg
#   inflating: food11/test/0694.jpg
#   inflating: food11/test/0695.jpg
#   inflating: food11/test/0696.jpg
#   inflating: food11/test/0697.jpg
#   inflating: food11/test/0698.jpg
#   inflating: food11/test/0699.jpg
#   inflating: food11/test/0700.jpg
#   inflating: food11/test/0701.jpg
#   inflating: food11/test/0702.jpg
#   inflating: food11/test/0703.jpg
#   inflating: food11/test/0704.jpg
#   inflating: food11/test/0705.jpg
#   inflating: food11/test/0706.jpg
#   inflating: food11/test/0707.jpg
#   inflating: food11/test/0708.jpg
#   inflating: food11/test/0709.jpg
#   inflating: food11/test/0710.jpg
#   inflating: food11/test/0711.jpg
#   inflating: food11/test/0712.jpg
#  extracting: food11/test/0713.jpg
#   inflating: food11/test/0714.jpg
#   inflating: food11/test/0715.jpg
#   inflating: food11/test/0716.jpg
#   inflating: food11/test/0717.jpg
#   inflating: food11/test/0718.jpg
#   inflating: food11/test/0719.jpg
#   inflating: food11/test/0720.jpg
#   inflating: food11/test/0721.jpg
#   inflating: food11/test/0722.jpg
#   inflating: food11/test/0723.jpg
#   inflating: food11/test/0724.jpg
#   inflating: food11/test/0725.jpg
#   inflating: food11/test/0726.jpg
#   inflating: food11/test/0727.jpg
#   inflating: food11/test/0728.jpg
#   inflating: food11/test/0729.jpg
#   inflating: food11/test/0730.jpg
#   inflating: food11/test/0731.jpg
#   inflating: food11/test/0732.jpg
#   inflating: food11/test/0733.jpg
#   inflating: food11/test/0734.jpg
#   inflating: food11/test/0735.jpg
#   inflating: food11/test/0736.jpg
#   inflating: food11/test/0737.jpg
#   inflating: food11/test/0738.jpg
#   inflating: food11/test/0739.jpg
#   inflating: food11/test/0740.jpg
#   inflating: food11/test/0741.jpg
#   inflating: food11/test/0742.jpg
#   inflating: food11/test/0743.jpg
#   inflating: food11/test/0744.jpg
#   inflating: food11/test/0745.jpg
#   inflating: food11/test/0746.jpg
#   inflating: food11/test/0747.jpg
#   inflating: food11/test/0748.jpg
#   inflating: food11/test/0749.jpg
#   inflating: food11/test/0750.jpg
#   inflating: food11/test/0751.jpg
#   inflating: food11/test/0752.jpg
#   inflating: food11/test/0753.jpg
#   inflating: food11/test/0754.jpg
#   inflating: food11/test/0755.jpg
#   inflating: food11/test/0756.jpg
#   inflating: food11/test/0757.jpg
#   inflating: food11/test/0758.jpg
#   inflating: food11/test/0759.jpg
#   inflating: food11/test/0760.jpg
#   inflating: food11/test/0761.jpg
#   inflating: food11/test/0762.jpg
#   inflating: food11/test/0763.jpg
#   inflating: food11/test/0764.jpg
#   inflating: food11/test/0765.jpg
#   inflating: food11/test/0766.jpg
#   inflating: food11/test/0767.jpg
#   inflating: food11/test/0768.jpg
#   inflating: food11/test/0769.jpg
#   inflating: food11/test/0770.jpg
#   inflating: food11/test/0771.jpg
#   inflating: food11/test/0772.jpg
#  extracting: food11/test/0773.jpg
#   inflating: food11/test/0774.jpg
#   inflating: food11/test/0775.jpg
#   inflating: food11/test/0776.jpg
#   inflating: food11/test/0777.jpg
#   inflating: food11/test/0778.jpg
#   inflating: food11/test/0779.jpg
#   inflating: food11/test/0780.jpg
#   inflating: food11/test/0781.jpg
#   inflating: food11/test/0782.jpg
#   inflating: food11/test/0783.jpg
#   inflating: food11/test/0784.jpg
#   inflating: food11/test/0785.jpg
#   inflating: food11/test/0786.jpg
#  extracting: food11/test/0787.jpg
#   inflating: food11/test/0788.jpg
#   inflating: food11/test/0789.jpg
#   inflating: food11/test/0790.jpg
#   inflating: food11/test/0791.jpg
#   inflating: food11/test/0792.jpg
#   inflating: food11/test/0793.jpg
#   inflating: food11/test/0794.jpg
#   inflating: food11/test/0795.jpg
#   inflating: food11/test/0796.jpg
#   inflating: food11/test/0797.jpg
#   inflating: food11/test/0798.jpg
#   inflating: food11/test/0799.jpg
#   inflating: food11/test/0800.jpg
#   inflating: food11/test/0801.jpg
#   inflating: food11/test/0802.jpg
#   inflating: food11/test/0803.jpg
#   inflating: food11/test/0804.jpg
#   inflating: food11/test/0805.jpg
#   inflating: food11/test/0806.jpg
#   inflating: food11/test/0807.jpg
#   inflating: food11/test/0808.jpg
#   inflating: food11/test/0809.jpg
#   inflating: food11/test/0810.jpg
#   inflating: food11/test/0811.jpg
#   inflating: food11/test/0812.jpg
#   inflating: food11/test/0813.jpg
#   inflating: food11/test/0814.jpg
#   inflating: food11/test/0815.jpg
#   inflating: food11/test/0816.jpg
#   inflating: food11/test/0817.jpg
#   inflating: food11/test/0818.jpg
#   inflating: food11/test/0819.jpg
#   inflating: food11/test/0820.jpg
#   inflating: food11/test/0821.jpg
#   inflating: food11/test/0822.jpg
#   inflating: food11/test/0823.jpg
#   inflating: food11/test/0824.jpg
#   inflating: food11/test/0825.jpg
#   inflating: food11/test/0826.jpg
#   inflating: food11/test/0827.jpg
#   inflating: food11/test/0828.jpg
#   inflating: food11/test/0829.jpg
#   inflating: food11/test/0830.jpg
#   inflating: food11/test/0831.jpg
#   inflating: food11/test/0832.jpg
#   inflating: food11/test/0833.jpg
#   inflating: food11/test/0834.jpg
#   inflating: food11/test/0835.jpg
#   inflating: food11/test/0836.jpg
#   inflating: food11/test/0837.jpg
#   inflating: food11/test/0838.jpg
#   inflating: food11/test/0839.jpg
#   inflating: food11/test/0840.jpg
#   inflating: food11/test/0841.jpg
#   inflating: food11/test/0842.jpg
#   inflating: food11/test/0843.jpg
#   inflating: food11/test/0844.jpg
#   inflating: food11/test/0845.jpg
#   inflating: food11/test/0846.jpg
#   inflating: food11/test/0847.jpg
#   inflating: food11/test/0848.jpg
#   inflating: food11/test/0849.jpg
#   inflating: food11/test/0850.jpg
#   inflating: food11/test/0851.jpg
#   inflating: food11/test/0852.jpg
#   inflating: food11/test/0853.jpg
#   inflating: food11/test/0854.jpg
#   inflating: food11/test/0855.jpg
#   inflating: food11/test/0856.jpg
#   inflating: food11/test/0857.jpg
#   inflating: food11/test/0858.jpg
#   inflating: food11/test/0859.jpg
#   inflating: food11/test/0860.jpg
#   inflating: food11/test/0861.jpg
#   inflating: food11/test/0862.jpg
#   inflating: food11/test/0863.jpg
#   inflating: food11/test/0864.jpg
#   inflating: food11/test/0865.jpg
#   inflating: food11/test/0866.jpg
#   inflating: food11/test/0867.jpg
#   inflating: food11/test/0868.jpg
#   inflating: food11/test/0869.jpg
#   inflating: food11/test/0870.jpg
#   inflating: food11/test/0871.jpg
#   inflating: food11/test/0872.jpg
#   inflating: food11/test/0873.jpg
#   inflating: food11/test/0874.jpg
#   inflating: food11/test/0875.jpg
#   inflating: food11/test/0876.jpg
#   inflating: food11/test/0877.jpg
#   inflating: food11/test/0878.jpg
#   inflating: food11/test/0879.jpg
#   inflating: food11/test/0880.jpg
#   inflating: food11/test/0881.jpg
#   inflating: food11/test/0882.jpg
#   inflating: food11/test/0883.jpg
#   inflating: food11/test/0884.jpg
#   inflating: food11/test/0885.jpg
#   inflating: food11/test/0886.jpg
#   inflating: food11/test/0887.jpg
#   inflating: food11/test/0888.jpg
#   inflating: food11/test/0889.jpg
#   inflating: food11/test/0890.jpg
#   inflating: food11/test/0891.jpg
#   inflating: food11/test/0892.jpg
#   inflating: food11/test/0893.jpg
#   inflating: food11/test/0894.jpg
#   inflating: food11/test/0895.jpg
#   inflating: food11/test/0896.jpg
#   inflating: food11/test/0897.jpg
#   inflating: food11/test/0898.jpg
#   inflating: food11/test/0899.jpg
#   inflating: food11/test/0900.jpg
#   inflating: food11/test/0901.jpg
#   inflating: food11/test/0902.jpg
#   inflating: food11/test/0903.jpg
#   inflating: food11/test/0904.jpg
#   inflating: food11/test/0905.jpg
#   inflating: food11/test/0906.jpg
#   inflating: food11/test/0907.jpg
#   inflating: food11/test/0908.jpg
#   inflating: food11/test/0909.jpg
#   inflating: food11/test/0910.jpg
#   inflating: food11/test/0911.jpg
#   inflating: food11/test/0912.jpg
#   inflating: food11/test/0913.jpg
#   inflating: food11/test/0914.jpg
#   inflating: food11/test/0915.jpg
#   inflating: food11/test/0916.jpg
#   inflating: food11/test/0917.jpg
#   inflating: food11/test/0918.jpg
#   inflating: food11/test/0919.jpg
#   inflating: food11/test/0920.jpg
#   inflating: food11/test/0921.jpg
#   inflating: food11/test/0922.jpg
#   inflating: food11/test/0923.jpg
#   inflating: food11/test/0924.jpg
#   inflating: food11/test/0925.jpg
#   inflating: food11/test/0926.jpg
#   inflating: food11/test/0927.jpg
#   inflating: food11/test/0928.jpg
#   inflating: food11/test/0929.jpg
#   inflating: food11/test/0930.jpg
#   inflating: food11/test/0931.jpg
#   inflating: food11/test/0932.jpg
#   inflating: food11/test/0933.jpg
#   inflating: food11/test/0934.jpg
#   inflating: food11/test/0935.jpg
#   inflating: food11/test/0936.jpg
#   inflating: food11/test/0937.jpg
#   inflating: food11/test/0938.jpg
#   inflating: food11/test/0939.jpg
#   inflating: food11/test/0940.jpg
#   inflating: food11/test/0941.jpg
#   inflating: food11/test/0942.jpg
#   inflating: food11/test/0943.jpg
#   inflating: food11/test/0944.jpg
#   inflating: food11/test/0945.jpg
#   inflating: food11/test/0946.jpg
#   inflating: food11/test/0947.jpg
#   inflating: food11/test/0948.jpg
#   inflating: food11/test/0949.jpg
#   inflating: food11/test/0950.jpg
#   inflating: food11/test/0951.jpg
#   inflating: food11/test/0952.jpg
#   inflating: food11/test/0953.jpg
#   inflating: food11/test/0954.jpg
#   inflating: food11/test/0955.jpg
#   inflating: food11/test/0956.jpg
#   inflating: food11/test/0957.jpg
#   inflating: food11/test/0958.jpg
#   inflating: food11/test/0959.jpg
#   inflating: food11/test/0960.jpg
#   inflating: food11/test/0961.jpg
#   inflating: food11/test/0962.jpg
#   inflating: food11/test/0963.jpg
#   inflating: food11/test/0964.jpg
#   inflating: food11/test/0965.jpg
#   inflating: food11/test/0966.jpg
#   inflating: food11/test/0967.jpg
#   inflating: food11/test/0968.jpg
#   inflating: food11/test/0969.jpg
#   inflating: food11/test/0970.jpg
#   inflating: food11/test/0971.jpg
#   inflating: food11/test/0972.jpg
#   inflating: food11/test/0973.jpg
#   inflating: food11/test/0974.jpg
#   inflating: food11/test/0975.jpg
#   inflating: food11/test/0976.jpg
#   inflating: food11/test/0977.jpg
#   inflating: food11/test/0978.jpg
#   inflating: food11/test/0979.jpg
#   inflating: food11/test/0980.jpg
#   inflating: food11/test/0981.jpg
#   inflating: food11/test/0982.jpg
#   inflating: food11/test/0983.jpg
#   inflating: food11/test/0984.jpg
#   inflating: food11/test/0985.jpg
#   inflating: food11/test/0986.jpg
#   inflating: food11/test/0987.jpg
#   inflating: food11/test/0988.jpg
#   inflating: food11/test/0989.jpg
#   inflating: food11/test/0990.jpg
#   inflating: food11/test/0991.jpg
#   inflating: food11/test/0992.jpg
#   inflating: food11/test/0993.jpg
#   inflating: food11/test/0994.jpg
#   inflating: food11/test/0995.jpg
#   inflating: food11/test/0996.jpg
#   inflating: food11/test/0997.jpg
#   inflating: food11/test/0998.jpg
#   inflating: food11/test/0999.jpg
#   inflating: food11/test/1000.jpg
#   inflating: food11/test/1001.jpg
#   inflating: food11/test/1002.jpg
#   inflating: food11/test/1003.jpg
#   inflating: food11/test/1004.jpg
#  extracting: food11/test/1005.jpg
#   inflating: food11/test/1006.jpg
#   inflating: food11/test/1007.jpg
#   inflating: food11/test/1008.jpg
#   inflating: food11/test/1009.jpg
#   inflating: food11/test/1010.jpg
#   inflating: food11/test/1011.jpg
#   inflating: food11/test/1012.jpg
#   inflating: food11/test/1013.jpg
#   inflating: food11/test/1014.jpg
#   inflating: food11/test/1015.jpg
#   inflating: food11/test/1016.jpg
#   inflating: food11/test/1017.jpg
#   inflating: food11/test/1018.jpg
#   inflating: food11/test/1019.jpg
#  extracting: food11/test/1020.jpg
#   inflating: food11/test/1021.jpg
#   inflating: food11/test/1022.jpg
#   inflating: food11/test/1023.jpg
#   inflating: food11/test/1024.jpg
#   inflating: food11/test/1025.jpg
#   inflating: food11/test/1026.jpg
#   inflating: food11/test/1027.jpg
#   inflating: food11/test/1028.jpg
#   inflating: food11/test/1029.jpg
#   inflating: food11/test/1030.jpg
#   inflating: food11/test/1031.jpg
#   inflating: food11/test/1032.jpg
#   inflating: food11/test/1033.jpg
#   inflating: food11/test/1034.jpg
#   inflating: food11/test/1035.jpg
#   inflating: food11/test/1036.jpg
#   inflating: food11/test/1037.jpg
#   inflating: food11/test/1038.jpg
#   inflating: food11/test/1039.jpg
#   inflating: food11/test/1040.jpg
#   inflating: food11/test/1041.jpg
#   inflating: food11/test/1042.jpg
#   inflating: food11/test/1043.jpg
#   inflating: food11/test/1044.jpg
#   inflating: food11/test/1045.jpg
#   inflating: food11/test/1046.jpg
#   inflating: food11/test/1047.jpg
#   inflating: food11/test/1048.jpg
#   inflating: food11/test/1049.jpg
#   inflating: food11/test/1050.jpg
#   inflating: food11/test/1051.jpg
#   inflating: food11/test/1052.jpg
#   inflating: food11/test/1053.jpg
#   inflating: food11/test/1054.jpg
#   inflating: food11/test/1055.jpg
#   inflating: food11/test/1056.jpg
#   inflating: food11/test/1057.jpg
#   inflating: food11/test/1058.jpg
#   inflating: food11/test/1059.jpg
#   inflating: food11/test/1060.jpg
#   inflating: food11/test/1061.jpg
#   inflating: food11/test/1062.jpg
#   inflating: food11/test/1063.jpg
#   inflating: food11/test/1064.jpg
#   inflating: food11/test/1065.jpg
#   inflating: food11/test/1066.jpg
#   inflating: food11/test/1067.jpg
#   inflating: food11/test/1068.jpg
#   inflating: food11/test/1069.jpg
#   inflating: food11/test/1070.jpg
#   inflating: food11/test/1071.jpg
#   inflating: food11/test/1072.jpg
#  extracting: food11/test/1073.jpg
#   inflating: food11/test/1074.jpg
#   inflating: food11/test/1075.jpg
#   inflating: food11/test/1076.jpg
#   inflating: food11/test/1077.jpg
#   inflating: food11/test/1078.jpg
#   inflating: food11/test/1079.jpg
#   inflating: food11/test/1080.jpg
#   inflating: food11/test/1081.jpg
#   inflating: food11/test/1082.jpg
#   inflating: food11/test/1083.jpg
#   inflating: food11/test/1084.jpg
#   inflating: food11/test/1085.jpg
#   inflating: food11/test/1086.jpg
#   inflating: food11/test/1087.jpg
#   inflating: food11/test/1088.jpg
#   inflating: food11/test/1089.jpg
#   inflating: food11/test/1090.jpg
#   inflating: food11/test/1091.jpg
#   inflating: food11/test/1092.jpg
#   inflating: food11/test/1093.jpg
#   inflating: food11/test/1094.jpg
#   inflating: food11/test/1095.jpg
#   inflating: food11/test/1096.jpg
#   inflating: food11/test/1097.jpg
#   inflating: food11/test/1098.jpg
#   inflating: food11/test/1099.jpg
#   inflating: food11/test/1100.jpg
#   inflating: food11/test/1101.jpg
#   inflating: food11/test/1102.jpg
#   inflating: food11/test/1103.jpg
#   inflating: food11/test/1104.jpg
#   inflating: food11/test/1105.jpg
#   inflating: food11/test/1106.jpg
#   inflating: food11/test/1107.jpg
#   inflating: food11/test/1108.jpg
#   inflating: food11/test/1109.jpg
#   inflating: food11/test/1110.jpg
#   inflating: food11/test/1111.jpg
#   inflating: food11/test/1112.jpg
#   inflating: food11/test/1113.jpg
#   inflating: food11/test/1114.jpg
#   inflating: food11/test/1115.jpg
#   inflating: food11/test/1116.jpg
#   inflating: food11/test/1117.jpg
#   inflating: food11/test/1118.jpg
#   inflating: food11/test/1119.jpg
#   inflating: food11/test/1120.jpg
#   inflating: food11/test/1121.jpg
#   inflating: food11/test/1122.jpg
#   inflating: food11/test/1123.jpg
#   inflating: food11/test/1124.jpg
#   inflating: food11/test/1125.jpg
#   inflating: food11/test/1126.jpg
#   inflating: food11/test/1127.jpg
#   inflating: food11/test/1128.jpg
#   inflating: food11/test/1129.jpg
#   inflating: food11/test/1130.jpg
#  extracting: food11/test/1131.jpg
#   inflating: food11/test/1132.jpg
#   inflating: food11/test/1133.jpg
#   inflating: food11/test/1134.jpg
#   inflating: food11/test/1135.jpg
#   inflating: food11/test/1136.jpg
#   inflating: food11/test/1137.jpg
#   inflating: food11/test/1138.jpg
#   inflating: food11/test/1139.jpg
#   inflating: food11/test/1140.jpg
#   inflating: food11/test/1141.jpg
#   inflating: food11/test/1142.jpg
#   inflating: food11/test/1143.jpg
#   inflating: food11/test/1144.jpg
#   inflating: food11/test/1145.jpg
#   inflating: food11/test/1146.jpg
#   inflating: food11/test/1147.jpg
#   inflating: food11/test/1148.jpg
#   inflating: food11/test/1149.jpg
#   inflating: food11/test/1150.jpg
#   inflating: food11/test/1151.jpg
#  extracting: food11/test/1152.jpg
#   inflating: food11/test/1153.jpg
#   inflating: food11/test/1154.jpg
#   inflating: food11/test/1155.jpg
#   inflating: food11/test/1156.jpg
#   inflating: food11/test/1157.jpg
#   inflating: food11/test/1158.jpg
#   inflating: food11/test/1159.jpg
#   inflating: food11/test/1160.jpg
#  extracting: food11/test/1161.jpg
#   inflating: food11/test/1162.jpg
#   inflating: food11/test/1163.jpg
#   inflating: food11/test/1164.jpg
#   inflating: food11/test/1165.jpg
#   inflating: food11/test/1166.jpg
#   inflating: food11/test/1167.jpg
#   inflating: food11/test/1168.jpg
#   inflating: food11/test/1169.jpg
#   inflating: food11/test/1170.jpg
#   inflating: food11/test/1171.jpg
#   inflating: food11/test/1172.jpg
#   inflating: food11/test/1173.jpg
#   inflating: food11/test/1174.jpg
#   inflating: food11/test/1175.jpg
#   inflating: food11/test/1176.jpg
#   inflating: food11/test/1177.jpg
#   inflating: food11/test/1178.jpg
#   inflating: food11/test/1179.jpg
#   inflating: food11/test/1180.jpg
#   inflating: food11/test/1181.jpg
#   inflating: food11/test/1182.jpg
#   inflating: food11/test/1183.jpg
#   inflating: food11/test/1184.jpg
#   inflating: food11/test/1185.jpg
#   inflating: food11/test/1186.jpg
#   inflating: food11/test/1187.jpg
#   inflating: food11/test/1188.jpg
#   inflating: food11/test/1189.jpg
#   inflating: food11/test/1190.jpg
#   inflating: food11/test/1191.jpg
#   inflating: food11/test/1192.jpg
#   inflating: food11/test/1193.jpg
#   inflating: food11/test/1194.jpg
#   inflating: food11/test/1195.jpg
#   inflating: food11/test/1196.jpg
#   inflating: food11/test/1197.jpg
#   inflating: food11/test/1198.jpg
#   inflating: food11/test/1199.jpg
#   inflating: food11/test/1200.jpg
#  extracting: food11/test/1201.jpg
#   inflating: food11/test/1202.jpg
#   inflating: food11/test/1203.jpg
#   inflating: food11/test/1204.jpg
#   inflating: food11/test/1205.jpg
#   inflating: food11/test/1206.jpg
#   inflating: food11/test/1207.jpg
#   inflating: food11/test/1208.jpg
#   inflating: food11/test/1209.jpg
#   inflating: food11/test/1210.jpg
#   inflating: food11/test/1211.jpg
#   inflating: food11/test/1212.jpg
#   inflating: food11/test/1213.jpg
#   inflating: food11/test/1214.jpg
#   inflating: food11/test/1215.jpg
#   inflating: food11/test/1216.jpg
#   inflating: food11/test/1217.jpg
#   inflating: food11/test/1218.jpg
#   inflating: food11/test/1219.jpg
#   inflating: food11/test/1220.jpg
#   inflating: food11/test/1221.jpg
#   inflating: food11/test/1222.jpg
#   inflating: food11/test/1223.jpg
#   inflating: food11/test/1224.jpg
#   inflating: food11/test/1225.jpg
#   inflating: food11/test/1226.jpg
#   inflating: food11/test/1227.jpg
#   inflating: food11/test/1228.jpg
#   inflating: food11/test/1229.jpg
#   inflating: food11/test/1230.jpg
#   inflating: food11/test/1231.jpg
#   inflating: food11/test/1232.jpg
#   inflating: food11/test/1233.jpg
#   inflating: food11/test/1234.jpg
#   inflating: food11/test/1235.jpg
#   inflating: food11/test/1236.jpg
#   inflating: food11/test/1237.jpg
#   inflating: food11/test/1238.jpg
#   inflating: food11/test/1239.jpg
#   inflating: food11/test/1240.jpg
#   inflating: food11/test/1241.jpg
#   inflating: food11/test/1242.jpg
#   inflating: food11/test/1243.jpg
#   inflating: food11/test/1244.jpg
#   inflating: food11/test/1245.jpg
#   inflating: food11/test/1246.jpg
#   inflating: food11/test/1247.jpg
#   inflating: food11/test/1248.jpg
#   inflating: food11/test/1249.jpg
#   inflating: food11/test/1250.jpg
#   inflating: food11/test/1251.jpg
#   inflating: food11/test/1252.jpg
#   inflating: food11/test/1253.jpg
#   inflating: food11/test/1254.jpg
#   inflating: food11/test/1255.jpg
#   inflating: food11/test/1256.jpg
#   inflating: food11/test/1257.jpg
#   inflating: food11/test/1258.jpg
#   inflating: food11/test/1259.jpg
#   inflating: food11/test/1260.jpg
#   inflating: food11/test/1261.jpg
# ...
#   inflating: food11/training/3_625.jpg
#   inflating: food11/training/3_626.jpg
#   inflating: food11/training/3_627.jpg
#   inflating: food11/training/3_628.jpg
#   inflating: food11/training/3_629.jpg
#   inflating: food11/training/3_63.jpg
#   inflating: food11/training/3_630.jpg
#   inflating: food11/training/3_631.jpg
#   inflating: food11/training/3_632.jpg
#   inflating: food11/training/3_633.jpg
#   inflating: food11/training/3_634.jpg
#   inflating: food11/training/3_635.jpg
#   inflating: food11/training/3_636.jpg
#   inflating: food11/training/3_637.jpg
#   inflating: food11/training/3_638.jpg
#   inflating: food11/training/3_639.jpg
#   inflating: food11/training/3_64.jpg
#   inflating: food11/training/3_640.jpg
#   inflating: food11/training/3_641.jpg
#   inflating: food11/training/3_642.jpg
#   inflating: food11/training/3_643.jpg
#   inflating: food11/training/3_644.jpg
#   inflating: food11/training/3_645.jpg
#   inflating: food11/training/3_646.jpg
#   inflating: food11/training/3_647.jpg
#   inflating: food11/training/3_648.jpg
#   inflating: food11/training/3_649.jpg
#   inflating: food11/training/3_65.jpg
#   inflating: food11/training/3_650.jpg
#   inflating: food11/training/3_651.jpg
#   inflating: food11/training/3_652.jpg
#   inflating: food11/training/3_653.jpg
#   inflating: food11/training/3_654.jpg
#   inflating: food11/training/3_655.jpg
#   inflating: food11/training/3_656.jpg
#   inflating: food11/training/3_657.jpg
#   inflating: food11/training/3_658.jpg
#   inflating: food11/training/3_659.jpg
#   inflating: food11/training/3_66.jpg
#   inflating: food11/training/3_660.jpg
#   inflating: food11/training/3_661.jpg
#   inflating: food11/training/3_662.jpg
#   inflating: food11/training/3_663.jpg
#   inflating: food11/training/3_664.jpg
#   inflating: food11/training/3_665.jpg
#   inflating: food11/training/3_666.jpg
#   inflating: food11/training/3_667.jpg
#   inflating: food11/training/3_668.jpg
#   inflating: food11/training/3_669.jpg
#   inflating: food11/training/3_67.jpg
#   inflating: food11/training/3_670.jpg
#   inflating: food11/training/3_671.jpg
#   inflating: food11/training/3_672.jpg
#   inflating: food11/training/3_673.jpg
#   inflating: food11/training/3_674.jpg
#   inflating: food11/training/3_675.jpg
#   inflating: food11/training/3_676.jpg
#   inflating: food11/training/3_677.jpg
#   inflating: food11/training/3_678.jpg
#   inflating: food11/training/3_679.jpg
#   inflating: food11/training/3_68.jpg
#   inflating: food11/training/3_680.jpg
#   inflating: food11/training/3_681.jpg
#   inflating: food11/training/3_682.jpg
#   inflating: food11/training/3_683.jpg
#   inflating: food11/training/3_684.jpg
#   inflating: food11/training/3_685.jpg
#   inflating: food11/training/3_686.jpg
#   inflating: food11/training/3_687.jpg
#   inflating: food11/training/3_688.jpg
#   inflating: food11/training/3_689.jpg
#   inflating: food11/training/3_69.jpg
#   inflating: food11/training/3_690.jpg
#   inflating: food11/training/3_691.jpg
#   inflating: food11/training/3_692.jpg
#   inflating: food11/training/3_693.jpg
#   inflating: food11/training/3_694.jpg
#   inflating: food11/training/3_695.jpg
#   inflating: food11/training/3_696.jpg
#   inflating: food11/training/3_697.jpg
#   inflating: food11/training/3_698.jpg
#   inflating: food11/training/3_699.jpg
#   inflating: food11/training/3_7.jpg
#   inflating: food11/training/3_70.jpg
#   inflating: food11/training/3_700.jpg
#   inflating: food11/training/3_701.jpg
#   inflating: food11/training/3_702.jpg
#   inflating: food11/training/3_703.jpg
#   inflating: food11/training/3_704.jpg
#   inflating: food11/training/3_705.jpg
#   inflating: food11/training/3_706.jpg
#   inflating: food11/training/3_707.jpg
#   inflating: food11/training/3_708.jpg
#   inflating: food11/training/3_709.jpg
#   inflating: food11/training/3_71.jpg
#   inflating: food11/training/3_710.jpg
#   inflating: food11/training/3_711.jpg
#   inflating: food11/training/3_712.jpg
#   inflating: food11/training/3_713.jpg
#   inflating: food11/training/3_714.jpg
#   inflating: food11/training/3_715.jpg
#   inflating: food11/training/3_716.jpg
#   inflating: food11/training/3_717.jpg
#   inflating: food11/training/3_718.jpg
#   inflating: food11/training/3_719.jpg
#   inflating: food11/training/3_72.jpg
#   inflating: food11/training/3_720.jpg
#   inflating: food11/training/3_721.jpg
#   inflating: food11/training/3_722.jpg
#   inflating: food11/training/3_723.jpg
#   inflating: food11/training/3_724.jpg
#   inflating: food11/training/3_725.jpg
#   inflating: food11/training/3_726.jpg
#   inflating: food11/training/3_727.jpg
#   inflating: food11/training/3_728.jpg
#   inflating: food11/training/3_729.jpg
#   inflating: food11/training/3_73.jpg
#   inflating: food11/training/3_730.jpg
#   inflating: food11/training/3_731.jpg
#   inflating: food11/training/3_732.jpg
#   inflating: food11/training/3_733.jpg
#   inflating: food11/training/3_734.jpg
#   inflating: food11/training/3_735.jpg
#   inflating: food11/training/3_736.jpg
#   inflating: food11/training/3_737.jpg
#   inflating: food11/training/3_738.jpg
#   inflating: food11/training/3_739.jpg
#   inflating: food11/training/3_74.jpg
#   inflating: food11/training/3_740.jpg
#   inflating: food11/training/3_741.jpg
#   inflating: food11/training/3_742.jpg
#   inflating: food11/training/3_743.jpg
#   inflating: food11/training/3_744.jpg
#   inflating: food11/training/3_745.jpg
#   inflating: food11/training/3_746.jpg
#   inflating: food11/training/3_747.jpg
#   inflating: food11/training/3_748.jpg
#   inflating: food11/training/3_749.jpg
#   inflating: food11/training/3_75.jpg
#   inflating: food11/training/3_750.jpg
#   inflating: food11/training/3_751.jpg
#   inflating: food11/training/3_752.jpg
#   inflating: food11/training/3_753.jpg
#   inflating: food11/training/3_754.jpg
#   inflating: food11/training/3_755.jpg
#   inflating: food11/training/3_756.jpg
#   inflating: food11/training/3_757.jpg
#   inflating: food11/training/3_758.jpg
#   inflating: food11/training/3_759.jpg
#   inflating: food11/training/3_76.jpg
#   inflating: food11/training/3_760.jpg
#   inflating: food11/training/3_761.jpg
#   inflating: food11/training/3_762.jpg
#   inflating: food11/training/3_763.jpg
#   inflating: food11/training/3_764.jpg
#   inflating: food11/training/3_765.jpg
#   inflating: food11/training/3_766.jpg
#   inflating: food11/training/3_767.jpg
#   inflating: food11/training/3_768.jpg
#   inflating: food11/training/3_769.jpg
#   inflating: food11/training/3_77.jpg
#   inflating: food11/training/3_770.jpg
#   inflating: food11/training/3_771.jpg
#   inflating: food11/training/3_772.jpg
#   inflating: food11/training/3_773.jpg
#   inflating: food11/training/3_774.jpg
#   inflating: food11/training/3_775.jpg
#   inflating: food11/training/3_776.jpg
#   inflating: food11/training/3_777.jpg
#   inflating: food11/training/3_778.jpg
#   inflating: food11/training/3_779.jpg
#   inflating: food11/training/3_78.jpg
#   inflating: food11/training/3_780.jpg
#   inflating: food11/training/3_781.jpg
#   inflating: food11/training/3_782.jpg
#   inflating: food11/training/3_783.jpg
#   inflating: food11/training/3_784.jpg
#   inflating: food11/training/3_785.jpg
#   inflating: food11/training/3_786.jpg
#   inflating: food11/training/3_787.jpg
#   inflating: food11/training/3_788.jpg
#   inflating: food11/training/3_789.jpg
#   inflating: food11/training/3_79.jpg
#   inflating: food11/training/3_790.jpg
#   inflating: food11/training/3_791.jpg
#   inflating: food11/training/3_792.jpg
#   inflating: food11/training/3_793.jpg
#   inflating: food11/training/3_794.jpg
#   inflating: food11/training/3_795.jpg
#   inflating: food11/training/3_796.jpg
#   inflating: food11/training/3_797.jpg
#   inflating: food11/training/3_798.jpg
#   inflating: food11/training/3_799.jpg
#   inflating: food11/training/3_8.jpg
#   inflating: food11/training/3_80.jpg
#   inflating: food11/training/3_800.jpg
#   inflating: food11/training/3_801.jpg
#   inflating: food11/training/3_802.jpg
#   inflating: food11/training/3_803.jpg
#   inflating: food11/training/3_804.jpg
#   inflating: food11/training/3_805.jpg
#   inflating: food11/training/3_806.jpg
#   inflating: food11/training/3_807.jpg
#   inflating: food11/training/3_808.jpg
#   inflating: food11/training/3_809.jpg
#   inflating: food11/training/3_81.jpg
#   inflating: food11/training/3_810.jpg
#   inflating: food11/training/3_811.jpg
#   inflating: food11/training/3_812.jpg
#   inflating: food11/training/3_813.jpg
#   inflating: food11/training/3_814.jpg
#   inflating: food11/training/3_815.jpg
#   inflating: food11/training/3_816.jpg
#   inflating: food11/training/3_817.jpg
#   inflating: food11/training/3_818.jpg
#   inflating: food11/training/3_819.jpg
#   inflating: food11/training/3_82.jpg
#   inflating: food11/training/3_820.jpg
#   inflating: food11/training/3_821.jpg
#   inflating: food11/training/3_822.jpg
#   inflating: food11/training/3_823.jpg
#   inflating: food11/training/3_824.jpg
#   inflating: food11/training/3_825.jpg
#   inflating: food11/training/3_826.jpg
#   inflating: food11/training/3_827.jpg
#   inflating: food11/training/3_828.jpg
#   inflating: food11/training/3_829.jpg
#   inflating: food11/training/3_83.jpg
#   inflating: food11/training/3_830.jpg
#   inflating: food11/training/3_831.jpg
#   inflating: food11/training/3_832.jpg
#   inflating: food11/training/3_833.jpg
#   inflating: food11/training/3_834.jpg
#   inflating: food11/training/3_835.jpg
#   inflating: food11/training/3_836.jpg
#   inflating: food11/training/3_837.jpg
#   inflating: food11/training/3_838.jpg
#   inflating: food11/training/3_839.jpg
#   inflating: food11/training/3_84.jpg
#   inflating: food11/training/3_840.jpg
#   inflating: food11/training/3_841.jpg
#   inflating: food11/training/3_842.jpg
#   inflating: food11/training/3_843.jpg
#   inflating: food11/training/3_844.jpg
#   inflating: food11/training/3_845.jpg
#   inflating: food11/training/3_846.jpg
#   inflating: food11/training/3_847.jpg
#   inflating: food11/training/3_848.jpg
#   inflating: food11/training/3_849.jpg
#   inflating: food11/training/3_85.jpg
#   inflating: food11/training/3_850.jpg
#   inflating: food11/training/3_851.jpg
#   inflating: food11/training/3_852.jpg
#   inflating: food11/training/3_853.jpg
#   inflating: food11/training/3_854.jpg
#   inflating: food11/training/3_855.jpg
#   inflating: food11/training/3_856.jpg
#   inflating: food11/training/3_857.jpg
#   inflating: food11/training/3_858.jpg
#   inflating: food11/training/3_859.jpg
#   inflating: food11/training/3_86.jpg
#   inflating: food11/training/3_860.jpg
#   inflating: food11/training/3_861.jpg
#   inflating: food11/training/3_862.jpg
#   inflating: food11/training/3_863.jpg
#   inflating: food11/training/3_864.jpg
#   inflating: food11/training/3_865.jpg
#   inflating: food11/training/3_866.jpg
#   inflating: food11/training/3_867.jpg
#   inflating: food11/training/3_868.jpg
#   inflating: food11/training/3_869.jpg
#   inflating: food11/training/3_87.jpg
#   inflating: food11/training/3_870.jpg
#   inflating: food11/training/3_871.jpg
#   inflating: food11/training/3_872.jpg
#   inflating: food11/training/3_873.jpg
#   inflating: food11/training/3_874.jpg
#   inflating: food11/training/3_875.jpg
#   inflating: food11/training/3_876.jpg
#   inflating: food11/training/3_877.jpg
#   inflating: food11/training/3_878.jpg
#   inflating: food11/training/3_879.jpg
#   inflating: food11/training/3_88.jpg
#   inflating: food11/training/3_880.jpg
#   inflating: food11/training/3_881.jpg
#   inflating: food11/training/3_882.jpg
#   inflating: food11/training/3_883.jpg
#   inflating: food11/training/3_884.jpg
#   inflating: food11/training/3_885.jpg
#   inflating: food11/training/3_886.jpg
#   inflating: food11/training/3_887.jpg
#   inflating: food11/training/3_888.jpg
#   inflating: food11/training/3_889.jpg
#   inflating: food11/training/3_89.jpg
#   inflating: food11/training/3_890.jpg
#   inflating: food11/training/3_891.jpg
#   inflating: food11/training/3_892.jpg
#   inflating: food11/training/3_893.jpg
#   inflating: food11/training/3_894.jpg
#   inflating: food11/training/3_895.jpg
#   inflating: food11/training/3_896.jpg
#   inflating: food11/training/3_897.jpg
#   inflating: food11/training/3_898.jpg
#   inflating: food11/training/3_899.jpg
#   inflating: food11/training/3_9.jpg
#   inflating: food11/training/3_90.jpg
#   inflating: food11/training/3_900.jpg
#   inflating: food11/training/3_901.jpg
#   inflating: food11/training/3_902.jpg
#   inflating: food11/training/3_903.jpg
#   inflating: food11/training/3_904.jpg
#   inflating: food11/training/3_905.jpg
#   inflating: food11/training/3_906.jpg
#   inflating: food11/training/3_907.jpg
#   inflating: food11/training/3_908.jpg
#   inflating: food11/training/3_909.jpg
#   inflating: food11/training/3_91.jpg
#   inflating: food11/training/3_910.jpg
#   inflating: food11/training/3_911.jpg
#   inflating: food11/training/3_912.jpg
#   inflating: food11/training/3_913.jpg
#   inflating: food11/training/3_914.jpg
#   inflating: food11/training/3_915.jpg
#   inflating: food11/training/3_916.jpg
#   inflating: food11/training/3_917.jpg
#   inflating: food11/training/3_918.jpg
#   inflating: food11/training/3_919.jpg
#   inflating: food11/training/3_92.jpg
#   inflating: food11/training/3_920.jpg
#   inflating: food11/training/3_921.jpg
#   inflating: food11/training/3_922.jpg
#   inflating: food11/training/3_923.jpg
#   inflating: food11/training/3_924.jpg
#   inflating: food11/training/3_925.jpg
#   inflating: food11/training/3_926.jpg
#   inflating: food11/training/3_927.jpg
#   inflating: food11/training/3_928.jpg
#   inflating: food11/training/3_929.jpg
#   inflating: food11/training/3_93.jpg
#   inflating: food11/training/3_930.jpg
#   inflating: food11/training/3_931.jpg
#   inflating: food11/training/3_932.jpg
#   inflating: food11/training/3_933.jpg
#   inflating: food11/training/3_934.jpg
#   inflating: food11/training/3_935.jpg
#   inflating: food11/training/3_936.jpg
#   inflating: food11/training/3_937.jpg
#   inflating: food11/training/3_938.jpg
#   inflating: food11/training/3_939.jpg
#   inflating: food11/training/3_94.jpg
#   inflating: food11/training/3_940.jpg
#   inflating: food11/training/3_941.jpg
#   inflating: food11/training/3_942.jpg
#   inflating: food11/training/3_943.jpg
#   inflating: food11/training/3_944.jpg
#   inflating: food11/training/3_945.jpg
#   inflating: food11/training/3_946.jpg
#   inflating: food11/training/3_947.jpg
#   inflating: food11/training/3_948.jpg
#   inflating: food11/training/3_949.jpg
#   inflating: food11/training/3_95.jpg
#   inflating: food11/training/3_950.jpg
#   inflating: food11/training/3_951.jpg
#   inflating: food11/training/3_952.jpg
#   inflating: food11/training/3_953.jpg
#   inflating: food11/training/3_954.jpg
#   inflating: food11/training/3_955.jpg
#   inflating: food11/training/3_956.jpg
#   inflating: food11/training/3_957.jpg
#   inflating: food11/training/3_958.jpg
#   inflating: food11/training/3_959.jpg
#   inflating: food11/training/3_96.jpg
#   inflating: food11/training/3_960.jpg
#   inflating: food11/training/3_961.jpg
#   inflating: food11/training/3_962.jpg
#   inflating: food11/training/3_963.jpg
#   inflating: food11/training/3_964.jpg
#   inflating: food11/training/3_965.jpg
#   inflating: food11/training/3_966.jpg
#   inflating: food11/training/3_967.jpg
#   inflating: food11/training/3_968.jpg
#   inflating: food11/training/3_969.jpg
#   inflating: food11/training/3_97.jpg
#   inflating: food11/training/3_970.jpg
#   inflating: food11/training/3_971.jpg
#   inflating: food11/training/3_972.jpg
#   inflating: food11/training/3_973.jpg
#   inflating: food11/training/3_974.jpg
#   inflating: food11/training/3_975.jpg
#   inflating: food11/training/3_976.jpg
#   inflating: food11/training/3_977.jpg

# %% [markdown]
# # Training

# %%
_exp_name = "sample"

# %%
# Import necessary packages.
import numpy as np
import pandas as pd
import torch
import os
import torch.nn as nn
import torchvision.transforms as transforms
from PIL import Image
# "ConcatDataset" and "Subset" are possibly useful when doing semi-supervised learning.
from torch.utils.data import ConcatDataset, DataLoader, Subset, Dataset
from torchvision.datasets import DatasetFolder, VisionDataset

# This is for the progress bar.
from tqdm.auto import tqdm
import random

# %%
myseed = 6666  # set a random seed for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %% [markdown]
# ## **Transforms**
# Torchvision provides lots of useful utilities for image preprocessing, data wrapping as well as data augmentation.
#
# Please refer to PyTorch official website for details about different transforms.

# %%
# Normally, We don't need augmentations in testing and validation.
# All we need here is to resize the PIL image and transform it into Tensor.
test_tfm = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    ),
])

# However, it is also possible to use augmentation in the testing phase.
# You may use train_tfm to produce a variety of images and then test using ensemble methods
train_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    transforms.Resize((128, 128)),
    # You may add some transforms here.
    transforms.RandomHorizontalFlip(0.5),
    transforms.RandomVerticalFlip(0.5),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    # ToTensor() should be the last one of the transforms.
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    ),
])

# %% [markdown]
# ## **Datasets**
# The data is labelled by the name, so we load images and label while calling '__getitem__'

# %%
class FoodDataset(Dataset):

    def __init__(self,path,tfm=test_tfm,files = None):
        super(FoodDataset).__init__()
        self.path = path
        self.files = sorted([os.path.join(path,x) for x in os.listdir(path) if x.endswith(".jpg")])
        if files != None:
            self.files = files
        print(f"One {path} sample",self.files[0])
        self.transform = tfm
  
    def __len__(self):
        return len(self.files)
  
    def __getitem__(self,idx):
        fname = self.files[idx]
        im = Image.open(fname)
        im = self.transform(im)
        #im = self.data[idx]
        try:
            label = int(fname.split("/")[-1].split("_")[0])
        except:
            label = -1 # test has no label
        return im,label

# %%
# class Classifier(nn.Module):
#     def __init__(self):
#         super(Classifier, self).__init__()
#         # torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
#         # torch.nn.MaxPool2d(kernel_size, stride, padding)
#         # input 維度 [3, 128, 128]
#         self.cnn = nn.Sequential(
#             nn.Conv2d(3, 64, 3, 1, 1),  # [64, 128, 128]
#             nn.BatchNorm2d(64),
#             nn.ReLU(),
#             nn.MaxPool2d(2, 2, 0),      # [64, 64, 64]

#             nn.Conv2d(64, 128, 3, 1, 1), # [128, 64, 64]
#             nn.BatchNorm2d(128),
#             nn.ReLU(),
#             nn.MaxPool2d(2, 2, 0),      # [128, 32, 32]

#             nn.Conv2d(128, 256, 3, 1, 1), # [256, 32, 32]
#             nn.BatchNorm2d(256),
#             nn.ReLU(),
#             nn.MaxPool2d(2, 2, 0),      # [256, 16, 16]

#             nn.Conv2d(256, 512, 3, 1, 1), # [512, 16, 16]
#             nn.BatchNorm2d(512),
#             nn.ReLU(),
#             nn.MaxPool2d(2, 2, 0),       # [512, 8, 8]
            
#             nn.Conv2d(512, 512, 3, 1, 1), # [512, 8, 8]
#             nn.BatchNorm2d(512),
#             nn.ReLU(),
#             nn.MaxPool2d(2, 2, 0),       # [512, 4, 4]
#         )
#         self.fc = nn.Sequential(
#             nn.Linear(512*4*4, 1024),
#             nn.ReLU(),
#             nn.Linear(1024, 512),
#             nn.ReLU(),
#             nn.Linear(512, 11)
#         )

#     def forward(self, x):
#         out = self.cnn(x)
#         out = out.view(out.size()[0], -1)
#         return self.fc(out)

from torchvision.models import resnet50

class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        self.resnet = resnet50(pretrained=False)
        fc = nn.Sequential(
            nn.Linear(2048, 512),
            nn.ReLU(),
            nn.Linear(512, 11)
        )
        self.resnet.fc = fc # 11 classes

    def forward(self, x):
        return self.resnet(x)

# %%
batch_size = 64
_dataset_dir = "./food11"
# Construct datasets.
# The argument "loader" tells how torchvision reads the data.
train_set = FoodDataset(os.path.join(_dataset_dir,"training"), tfm=train_tfm)
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)
valid_set = FoodDataset(os.path.join(_dataset_dir,"validation"), tfm=test_tfm)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)

# %%
# "cuda" only when GPUs are available.
device = "cuda:2" if torch.cuda.is_available() else "cpu"

# The number of training epochs and patience.
n_epochs = 200
patience = 40 # If no improvement in 'patience' epochs, early stop

# Initialize a model, and put it on the device specified.
model = Classifier().to(device)

# For the classification task, we use cross-entropy as the measurement of performance.
criterion = nn.CrossEntropyLoss()

# Initialize optimizer, you may fine-tune some hyperparameters such as learning rate on your own.
optimizer = torch.optim.Adam(model.parameters(), lr=0.0003, weight_decay=1e-5) 

# Initialize trackers, these are not parameters and should not be changed
stale = 0
best_acc = 0

for epoch in range(n_epochs):

    # ---------- Training ----------
    # Make sure the model is in train mode before training.
    model.train()

    # These are used to record information in training.
    train_loss = []
    train_accs = []

    for batch in tqdm(train_loader):

        # A batch consists of image data and corresponding labels.
        imgs, labels = batch
        # print(labels)
        # imgs = imgs.half()
        # print(imgs.shape,labels.shape)

        # Forward the data. (Make sure data and model are on the same device.)
        logits = model(imgs.to(device))
        # print(logits)

        # Calculate the cross-entropy loss.
        # We don't need to apply softmax before computing cross-entropy as it is done automatically.
        loss = criterion(logits, labels.to(device))

        # Gradients stored in the parameters in the previous step should be cleared out first.
        optimizer.zero_grad()

        # Compute the gradients for parameters.
        loss.backward()

        # Clip the gradient norms for stable training.
        grad_norm = nn.utils.clip_grad_norm_(model.parameters(), max_norm=10)

        # Update the parameters with computed gradients.
        optimizer.step()

        # Compute the accuracy for current batch.
        acc = (logits.argmax(dim=-1) == labels.to(device)).float().mean()

        # Record the loss and accuracy.
        train_loss.append(loss.item())
        train_accs.append(acc)
        
    train_loss = sum(train_loss) / len(train_loss)
    train_acc = sum(train_accs) / len(train_accs)

    # Print the information.
    print(f"[ Train | {epoch + 1:03d}/{n_epochs:03d} ] loss = {train_loss:.5f}, acc = {train_acc:.5f}")

    # ---------- Validation ----------
    # Make sure the model is in eval mode so that some modules like dropout are disabled and work normally.
    model.eval()

    # These are used to record information in validation.
    valid_loss = []
    valid_accs = []

    # Iterate the validation set by batches.
    for batch in tqdm(valid_loader):

        # A batch consists of image data and corresponding labels.
        imgs, labels = batch
        #imgs = imgs.half()

        # We don't need gradient in validation.
        # Using torch.no_grad() accelerates the forward process.
        with torch.no_grad():
            logits = model(imgs.to(device))

        # We can still compute the loss (but not the gradient).
        loss = criterion(logits, labels.to(device))

        # Compute the accuracy for current batch.
        acc = (logits.argmax(dim=-1) == labels.to(device)).float().mean()

        # Record the loss and accuracy.
        valid_loss.append(loss.item())
        valid_accs.append(acc)
        #break

    # The average loss and accuracy for entire validation set is the average of the recorded values.
    valid_loss = sum(valid_loss) / len(valid_loss)
    valid_acc = sum(valid_accs) / len(valid_accs)

    # Print the information.
    print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {valid_loss:.5f}, acc = {valid_acc:.5f}")


    # update logs
    if valid_acc > best_acc:
        with open(f"./{_exp_name}_log.txt","a") as f:
            f.write(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {valid_loss:.5f}, acc = {valid_acc:.5f} -> best")
    else:
        with open(f"./{_exp_name}_log.txt","a") as f:
            f.write(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {valid_loss:.5f}, acc = {valid_acc:.5f}")


    # save models
    if valid_acc > best_acc:
        print(f"Best model found at epoch {epoch}, saving model")
        torch.save(model.state_dict(), f"{_exp_name}_best.ckpt") # only save best to prevent output memory exceed error
        best_acc = valid_acc
        stale = 0
    else:
        stale += 1
        if stale > patience:
            print(f"No improvment {patience} consecutive epochs, early stopping")
            break

# %%
test_set = FoodDataset(os.path.join(_dataset_dir,"test"), tfm=test_tfm)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

# %% [markdown]
# # Testing and generate prediction CSV

# %%
model_best = Classifier().to(device)
model_best.load_state_dict(torch.load(f"{_exp_name}_best.ckpt"))
model_best.eval()
prediction = []
K = 5 
alpha = 0.8
TTA_loader = [DataLoader(FoodDataset(os.path.join(_dataset_dir,"test"), tfm=train_tfm), batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True) for _ in range(K)]
with torch.no_grad():
    for batches in zip(test_loader, *TTA_loader):
        x_test, _ = batches[0]
        test_pred = model_best(x_test.to(device))
        sum_logits = torch.zeros_like(test_pred)
        for i in range(K):
            x_tta, _ = batches[i + 1]
            sum_logits += model_best(x_tta.to(device))
        avg_logits = sum_logits / K
        test_pred = alpha * test_pred + (1 - alpha) * avg_logits
        test_label = np.argmax(test_pred.cpu().data.numpy(), axis=1)
        prediction += test_label.squeeze().tolist()

# %%
# model_best = Classifier().to(device)
# model_best.load_state_dict(torch.load(f"{_exp_name}_best.ckpt"))
# model_best.eval()
# prediction = []
# with torch.no_grad():
#     for data,_ in test_loader:
#         test_pred = model_best(data.to(device))
#         test_label = np.argmax(test_pred.cpu().data.numpy(), axis=1)
#         prediction += test_label.squeeze().tolist()

# %%
#create test csv
def pad4(i):
    return "0"*(4-len(str(i)))+str(i)
df = pd.DataFrame()
df["Id"] = [pad4(i) for i in range(1,len(test_set)+1)]
df["Category"] = prediction
df.to_csv("submission.csv",index = False)

# %% [markdown]
# # Q1. Augmentation Implementation
# ## Implement augmentation by finishing train_tfm in the code with image size of your choice.
# ## Directly copy the following block and paste it on GradeScope after you finish the code
# ### Your train_tfm must be capable of producing 5+ different results when given an identical image multiple times.
# ### Your  train_tfm in the report can be different from train_tfm in your training code.

# %%
train_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    transforms.Resize((128, 128)),
    # You need to add some transforms here.
    transforms.ToTensor(),
])

# %% [markdown]
# # Q2. Residual Implementation
# ![](https://i.imgur.com/GYsq1Ap.png)
# ## Directly copy the following block and paste it on GradeScope after you finish the code

# %%
from torch import nn
class Residual_Network(nn.Module):
    def __init__(self):
        super(Residual_Network, self).__init__()
        
        self.cnn_layer1 = nn.Sequential(
            nn.Conv2d(3, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
        )

        self.cnn_layer2 = nn.Sequential(
            nn.Conv2d(64, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
        )

        self.cnn_layer3 = nn.Sequential(
            nn.Conv2d(64, 128, 3, 2, 1),
            nn.BatchNorm2d(128),
        )

        self.cnn_layer4 = nn.Sequential(
            nn.Conv2d(128, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
        )
        self.cnn_layer5 = nn.Sequential(
            nn.Conv2d(128, 256, 3, 2, 1),
            nn.BatchNorm2d(256),
        )
        self.cnn_layer6 = nn.Sequential(
            nn.Conv2d(256, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
        )
        self.fc_layer = nn.Sequential(
            nn.Linear(256* 32* 32, 256),
            nn.ReLU(),
            nn.Linear(256, 11)
        )
        self.relu = nn.ReLU()

    def forward(self, x):
        # input (x): [batch_size, 3, 128, 128]
        # output: [batch_size, 11]

        # Extract features by convolutional layers.
        x1 = self.cnn_layer1(x)
        
        x1 = self.relu(x1)
        
        x2 = self.cnn_layer2(x1)
        
        x2 = self.relu(x2)
        
        x3 = self.cnn_layer3(x2)
        
        x3 = self.relu(x3)
        
        x4 = self.cnn_layer4(x3)
        
        x4 = self.relu(x4)
        
        x5 = self.cnn_layer5(x4)
        
        x5 = self.relu(x5)
        
        x6 = self.cnn_layer6(x5)
        
        x6 = self.relu(x6)
        
        # The extracted feature map must be flatten before going to fully-connected layers.
        xout = x6.flatten(1)

        # The features are transformed by fully-connected layers to obtain the final logits.
        xout = self.fc_layer(xout)
        return xout
